# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
kc = pd.read_csv('./source/kc_house_data.csv')

# %%
kc = kc.groupby('zipcode').nunique()

# %%
# Out:
# <bound method NDFrame.describe of                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
# ...

# %% [markdown]
# # display(kc[0:20

# %%
plt.figure(figsize=(20,12))
plt.hist(x=kc['price'], bins=1000)
plt.show()

# %%
corr = kc.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_921e5d04_3932_11ea_95ee_e0accb79c1b2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_921e5d04_3932_11ea_95ee_e0accb79c1b2row0_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_921e5d04_3932_11ea_95ee_e0accb79c1b2row0_col2 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_921e5d04_3932_11ea_95ee_e0accb79c1b2row0_col3 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_921e5d04_3932_11ea_95ee_e0accb79c1b2row0_col4 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_921e5d04_3932_11ea_95ee_e0accb79c1b2row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_921e5d04_3932_11ea_95ee_e0accb79c1b2row0_col6 {
#             background-color:  #d6d6e9;
#             color:  #000000;
# ...

# %%
kc.duplicated().isna().any()
# Out:
# False

# %%
#Import Library
#Import other necessary libraries like pandas, numpy...
from sklearn import tree
#Assumed you have, X (predictor) and Y (target) for training data set and x_test(predictor) of test_dataset
# Create tree object 
model = tree.DecisionTreeClassifier(criterion='gini') # for classification, here you can change the algorithm as gini or entropy (information gain) by default it is gini  
# model = tree.DecisionTreeRegressor() for regression
# Train the model using the training sets and check score
model.fit(X, y)
model.score(X, y)
#Predict Output
predicted= model.predict(x_test
# Out:
#   File "<ipython-input-8-9525fe8d6ef4>", line 12
#     predicted= model.predict(x_test
#                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
# importing required libraries
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# read the train and test dataset
train_data = kc[0:18000].drop(columns=['date', 'sqft_basement', 'waterfront', 'view', 'yr_renovated'])
test_data = kc[18000:21000].drop(columns=['date', 'sqft_basement', 'waterfront', 'view', 'yr_renovated'])

# shape of the dataset
print('Shape of training data :',train_data.shape)
print('Shape of testing data :',test_data.shape)

# Now, we need to predict the missing target variable in the test data
# target variable - Survived

# seperate the independent and target variable on training data
train_x = train_data.drop(columns=['price'],axis=1)
train_y = train_data['price']

# seperate the independent and target variable on testing data
test_x = test_data.drop(columns=['price'],axis=1)
test_y = test_data['price']

'''
'''
model = GradientBoostingClassifier(n_estimators=100,max_depth=5)

# fit the model with the training data
model.fit(train_x,train_y)

# predict the target on the train dataset
predict_train = model.predict(train_x)
print('\nTarget on train data',predict_train) 

# Accuray Score on train dataset
accuracy_train = accuracy_score(train_y,predict_train)
print('\naccuracy_score on train dataset : ', accuracy_train)

# predict the target on the test dataset
predict_test = model.predict(test_x)
print('\nTarget on test data',predict_test) 

# Accuracy Score on test dataset
accuracy_test = accuracy_score(test_y,predict_test)
print('\naccuracy_score on test dataset : ', accuracy_test)
# Out:
# Shape of training data : (18000, 16)
# Shape of testing data : (3000, 16)

# %%
print(accuracy_test)

# %%
sns.pairpl
